# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uReq
import logging

# %%
flipcart_url="https://www.flipkart.com/search?q=" + "realme11pro+"
response = requests.get(flipcart_url)

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=realme11pro+'

# %%
urlclient= uReq(flipcart_url)

# %%
urlclient

# %%
flipcard_page =urlclient.read()

# %%
flipcard_html = bs(response.text, 'html.parser')

# %%
flipcard_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/" +"realme-11-pro-5g-sunrise-beige-256-gb/p/itm5647cce338e55?pid=MOBGPU8HQQYQN8XT&lid=LSTMOBGPU8HQQYQN8XTW3I0BX&marketplace=FLIPKART&q=realme11pro+&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=97046476-df47-4b25-ba66-4490cd95d772.MOBGPU8HQQYQN8XT.SEARCH&ppt=None&ppn=None&ssid=fm1lrydbsw0000001722597515764&qH=8e9ae68ee4a05899"
# Out:
# 'https://www.flipkart.com/realme-11-pro-5g-sunrise-beige-256-gb/p/itm5647cce338e55?pid=MOBGPU8HQQYQN8XT&lid=LSTMOBGPU8HQQYQN8XTW3I0BX&marketplace=FLIPKART&q=realme11pro+&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=97046476-df47-4b25-ba66-4490cd95d772.MOBGPU8HQQYQN8XT.SEARCH&ppt=None&ppn=None&ssid=fm1lrydbsw0000001722597515764&qH=8e9ae68ee4a05899'

# %%
bigbox = flipcard_html.find_all("div", {"class": "cPHDOP col-12-12"})

# %%
print(f"Number of elements found: {len(bigbox)}")
# Out:
# Number of elements found: 27

# %%
del bigbox[0:3]

# %%
productlink="https://www.flipkart.com"+bigbox[3].div.div.div.a['href']

# %%
product_req=requests.get(productlink)

# %%
productlink
# Out:
# 'https://www.flipkart.com/realme-11-pro-5g-oasis-green-128-gb/p/itm3f783627a36ec?pid=MOBGQWWXAKJNMH2D&lid=LSTMOBGQWWXAKJNMH2DJADI1Z&marketplace=FLIPKART&q=realme11pro+&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=4d046076-6edc-4449-92aa-00dacf951bc8.MOBGQWWXAKJNMH2D.SEARCH&ppt=None&ppn=None&ssid=qgeqj5ssj40000001722608869351&qH=8e9ae68ee4a05899'

# %%
product_html=bs(product_req.text,'html.parser')

# %%
comment_box=product_html.find_all("div",{"class":"col EPCmJX"})

# %%
comment_box
# Out:
# [<div class="col EPCmJX"><div class="row"><div class="XQDdHH Ga3i8K">4<img class="Rza2QY" src="..."/></div><p class="z9E0IG">Really Nice</p></div><div class="row"><div class="ZmyHeo"><div><div class="">Good 👍</div><span class="wTYmpv"><span>READ MORE</span></span></div></div></div><div class="xmAgz5 pVVA7t"><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_bb5416273b0741f986db320327870cdc.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_04e925df8b4349209cbee7ebac5e5028.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="Be4x5X d517go" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_00e37a4f4e3b4a05985e7ba4d97abd87.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div></div><div cla
# ...

# %%
# Iterate through each comment box
for box in comment_box:
    # Find all p elements and filter by class manually
    p_tags = box.find_all("p")
    
    for p in p_tags:
        if "_2NsDsF" in p.get("class", []) and "AwS1CA" in p.get("class", []):
            print(p.text)
# Out:
# Chandru Chandru
# Flipkart Customer
# Bhanu Verma
# Alamdaar Husain siddiki
# Sai Kiran Katayath
# Nawaz MJJ
# Suraj Singh  Rajput
# Vishal singh
# Shubhchandra Jha
# Rahul Yadav

# %%
for i in bigbox:
    print("https://www.flipkart.com" +i.div.div.div.a['href'])
# Out:
# https://www.flipkart.com/realme-11-pro-5g-sunrise-beige-256-gb/p/itm3f783627a36ec?pid=MOBGPUNGNFZTHKHG&lid=LSTMOBGPUNGNFZTHKHGVH5UF3&marketplace=FLIPKART&q=realme11pro+&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=4d046076-6edc-4449-92aa-00dacf951bc8.MOBGPUNGNFZTHKHG.SEARCH&ppt=None&ppn=None&ssid=qgeqj5ssj40000001722608869351&qH=8e9ae68ee4a05899
# https://www.flipkart.com/realme-11-pro-5g-astral-black-256-gb/p/itm3f783627a36ec?pid=MOBGPUNGNHJM8HKS&lid=LSTMOBGPUNGNHJM8HKSIH9GIW&marketplace=FLIPKART&q=realme11pro+&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=4d046076-6edc-4449-92aa-00dacf951bc8.MOBGPUNGNHJM8HKS.SEARCH&ppt=None&ppn=None&ssid=qgeqj5ssj40000001722608869351&qH=8e9ae68ee4a05899
# ...

# %%
print("anmol")
# Out:
# anmol
